# %%
import pandas as pd 
import numpy as np

# %%
NFL_Data = pd.read_csv("dataset_.csv")

# %%
NFL_Data.head()
# Out:
#          date      away     home  first_downs_away  first_downs_home  \
# 0  2002-09-05     49ers   Giants                13                21
# 1  2002-09-08      Jets    Bills                18                26
# 2  2002-09-08   Vikings    Bears                19                20
# 3  2002-09-08  Chargers  Bengals                27                13
# 4  2002-09-08    Chiefs   Browns                24                24
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0             4-12             9-16               0-0               0-1
# 1              2-8             7-17               0-0               2-2
# 2             5-13             7-13               0-0               0-0
# 3             6-10             4-11               0-0               0-0
# 4             5-11             4-11               0-0               0-0
#
#    passing_yards_away  ...  redzone_away  redzone_home  drives_away  \
# ...

# %%
Cleaned_NFL_Data = NFL_Data[['date','away','home','turnovers_away','turnovers_home','possession_away','possession_home','score_away','score_home']]
Cleaned_NFL_Data.head()
# Out:
#          date      away     home  turnovers_away  turnovers_home  \
# 0  2002-09-05     49ers   Giants               1               3
# 1  2002-09-08      Jets    Bills               1               3
# 2  2002-09-08   Vikings    Bears               3               2
# 3  2002-09-08  Chargers  Bengals               0               1
# 4  2002-09-08    Chiefs   Browns               1               1
#
#   possession_away possession_home  score_away  score_home
# 0           27:32           32:28          16          13
# 1           21:06           39:08          37          31
# 2           31:31           28:29          23          27
# 3           37:48           22:12          34           6
# 4           30:16           29:44          40          39

# %%
Cleaned_NFL_Data.to_csv("Cleaned_NFL_Data.csv",index=0)
